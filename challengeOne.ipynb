# %%
#author...................john doe
#descrptionn..............the python challenge

# %%
while True: 
   score = int(input("Enter score (or -1 to quit): ")) 
  if score == -1: 
 break 
  if score >= 80: 
     print("Level 4") 
elif score >= 70: 
     print("Level 3") 
elif score >= 60: 
    print("Level 2") 
else: 
    print("Level 1")
